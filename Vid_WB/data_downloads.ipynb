# %% [markdown]
# ### Data Sources
#
# * World bank has a ton of data https://data.worldbank.org/
# * OECD has a lot of useful data https://data.oecd.org/
#
#
# Read up on Pandas datareader, it has so many data sources that we can pull from. Almost anywhere.
# https://pandas-datareader.readthedocs.io/en/latest/
#
# Also more data sources here from other python functions here. https://github.com/wilsonfreitas/awesome-quant#data-sources
#
#
# I would recommend that we do our data downloading using these convenient packages and then use reticulate to pass that data over into R. For now just focus on getting the most interesting data!!

# %%
from datetime import datetime, date, time
import pandas_datareader as pdr
from pandas_datareader import wb

# %%
country_list = wb.get_countries()
dict_cols = {'NY.GDP.PCAP.KD' : 'gdp_per_cap', 'NV.AGR.TOTL.ZS' : 'agri_perc_gdp', 
             'SL.AGR.EMPL.ZS' : 'agg.empl.agri.perc',
            'SP.RUR.TOTL.ZS' : 'rural.pop.perc',
            'SL.TLF.CACT.ZS' : 'lfpr_15up',
            'SP.POP.TOTL' : 'pop.tot'}

# %%
country_list
# Out:
#     iso3c iso2c                                               name  \
# 0     ABW    AW                                              Aruba
# 1     AFG    AF                                        Afghanistan
# 2     AFR    A9                                             Africa
# 3     AGO    AO                                             Angola
# 4     ALB    AL                                            Albania
# ..    ...   ...                                                ...
# 299   XZN    A5  Sub-Saharan Africa excluding South Africa and ...
# 300   YEM    YE                                        Yemen, Rep.
# 301   ZAF    ZA                                       South Africa
# 302   ZMB    ZM                                             Zambia
# 303   ZWE    ZW                                           Zimbabwe
#
#                          region  \
# 0    Latin America & Caribbean
# 1                    South Asia
# 2                    Aggregates
# 3           Sub-Saharan Africa
# 4         Europe & Central Asia
# ..                          ...
# 299                  Aggregates
# 300  Middle East & North Africa
# 301         Sub-Saharan Africa
# 302         Sub-Saharan Africa
# 303         Sub-Saharan Africa
#
#                                            adminregion          incomeLevel  \
# 0                                                               High income
# 1                                           South Asia           Low income
# 2                                                                Aggregates
# 3           Sub-Saharan Africa (excluding high income)  Lower middle income
# 4        Europe & Central Asia (excluding high income)  Upper middle income
# ..                                                 ...                  ...
# 299                                                              Aggregates
# 300  Middle East & North Africa (excluding high inc...           Low income
# 301         Sub-Saharan Africa (excluding high income)  Upper middle income
# 302         Sub-Saharan Africa (excluding high income)  Lower middle income
# 303         Sub-Saharan Africa (excluding high income)  Lower middle income
#
#         lendingType capitalCity  longitude  latitude
# 0    Not classified  Oranjestad   -70.0167  12.51670
# 1               IDA       Kabul    69.1761  34.52280
# 2        Aggregates                    NaN       NaN
# 3              IBRD      Luanda    13.2420  -8.81155
# 4              IBRD      Tirane    19.8172  41.33170
# ..              ...         ...        ...       ...
# 299      Aggregates                    NaN       NaN
# 300             IDA      Sana'a    44.2075  15.35200
# 301            IBRD    Pretoria    28.1871 -25.74600
# 302             IDA      Lusaka    28.2937 -15.39820
# 303           Blend      Harare    31.0672 -17.83120
#
# [304 rows x 10 columns]

# %%
test = pdr.wb.search('literacy')

# %%
test
# Out:
#                                    id  \
# 26            1.1_YOUTH.LITERACY.RATE
# 696    8.3.15_GHA.LITERACY.P3.LETTERS
# 700    8.3.16_GHA.LITERACY.P5.LETTERS
# 704      8.3.17_GHA.LITERACY.P3.WORDS
# 708      8.3.18_GHA.LITERACY.P5.WORDS
# ...                               ...
# 12831                UIS.LR.AG25T64.M
# 12832                     UIS.LR.AG65
# 12833                   UIS.LR.AG65.F
# 12834                 UIS.LR.AG65.GPI
# 12835                   UIS.LR.AG65.M
#
#                                                     name unit  \
# 26     Literacy rate, youth total (% of people ages 1...
# 696    Making the Grade Scores in Ghana, P3, Literacy...
# 700    Making the Grade Scores in Ghana, P5, Literacy...
# 704    Making the Grade Scores in Ghana, P3 Literacy ...
# 708    Making the Grade Scores in Ghana, P5, Literacy...
# ...                                                  ...  ...
# 12831    Literacy rate, population 25-64 years, male (%)
# 12832  Elderly literacy rate, population 65+ years, b...
# 12833  Elderly literacy rate, population 65+ years, f...
# 12834  Elderly literacy rate, population 65+ years, g...
# 12835  Elderly literacy rate, population 65+ years, m...
#
#                                  source  \
# 26     Global Partnership for Education
# 696    Global Partnership for Education
# 700    Global Partnership for Education
# 704    Global Partnership for Education
# 708    Global Partnership for Education
# ...                                 ...
# 12831              Education Statistics
# 12832              Education Statistics
# 12833              Education Statistics
# 12834              Education Statistics
# 12835              Education Statistics
#
#                                               sourceNote  \
# 26     The number of persons aged 15 to 24 years who ...
# 696    Mean score calculated for the results of the n...
# 700    Mean letters per minute read in the national a...
# 704    Mean score calculated for the results of the n...
# 708    Mean words per minute read in the national ass...
# ...                                                  ...
# 12831  Percentage of the male population between age ...
# 12832  Percentage of the population age 65 and above ...
# 12833  Percentage of females age 65 and above who can...
# 12834  Ratio of female elderly literacy rate to the m...
# 12835  Percentage of males age 65 and above who can, ...
#
#                                       sourceOrganization topics
# 26     b'Source of information: UNESCO Institute for ...
# 696    b'Data were collected from national and other ...
# 700    b'Data were collected from national and other ...
# 704    b'Data were collected from national and other ...
# 708    b'Data were collected from national and other ...
# ...                                                  ...    ...
# 12831                 b'UNESCO Institute for Statistics'
# 12832                 b'UNESCO Institute for Statistics'
# 12833                 b'UNESCO Institute for Statistics'
# 12834                 b'UNESCO Institute for Statistics'
# 12835                 b'UNESCO Institute for Statistics'
#
# [82 rows x 7 columns]

# %%
wb_data_raw = pdr.wb.download(indicator = [key for key in dict_cols.keys()], country = 'all', start = 1960, end = date.today().year)

# %%
wb_data_raw.head(10)
# Out:
#                  NY.GDP.PCAP.KD  NV.AGR.TOTL.ZS  SL.AGR.EMPL.ZS  \
# country    year
# Arab World 2019             NaN             NaN       21.365165
#            2018     6452.473304        5.150411       21.436991
#            2017     6444.249263        5.351102       21.485942
#            2016     6515.610951        5.477818       21.472110
#            2015     6430.297031        5.494414       21.581509
#            2014     6354.798378        5.189001       22.066166
#            2013     6337.464233        5.231652       22.217672
#            2012     6279.462714        5.007932       22.289856
#            2011     6021.781113        5.070918       23.071304
#            2010     5946.258579        5.175306       23.207374
#
#                  SP.RUR.TOTL.ZS  SL.TLF.CACT.ZS  SP.POP.TOTL
# country    year
# Arab World 2019             NaN       48.258672          NaN
#            2018       41.074581       48.272323  419790588.0
#            2017       41.358517       48.266518  411898965.0
#            2016       41.654725       48.298005  404024433.0
#            2015       41.968533       48.420952  396028278.0
#            2014       42.307520       48.754935  387907748.0
#            2013       42.599061       48.966527  379705719.0
#            2012       42.901463       48.721328  371443547.0
#            2011       43.208052       48.569831  363158703.0
#            2010       43.559121       48.454433  354890042.0
